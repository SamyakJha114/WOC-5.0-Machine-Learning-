# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import random

# %%
df = pd.read_csv("/content/drive/MyDrive/Project(WOC)/polynomial_train.csv" )
X_train = np.array(df.iloc[0:45000,1:4],dtype = 'float64')
Y_train = np.array(df.iloc[0:45000,4:5],dtype = 'float64')
X_CVS = np.array(df.iloc[45000:50000,1:4],dtype = 'float64')
Y_CVS = np.array(df.iloc[45000:50000,4:5],dtype = 'float64')

# %%
X_train.shape
# Out:
# (45000, 3)

# %%
J = []
iterations = []

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Project(WOC)/polynomial_test_data.csv" )
X_test = np.array(df1.iloc[0:20000,1:4])

# %%
class Polynomial_Regression:
  def __init__(self,X,Y,highest_degree,learning_rate,epoches,lamda):
    # We will have a polynomial with highest degree as degree in each feature in the model
    self.degree = highest_degree
    X_transform = self.transform(X)
    self.w = np.zeros((1,X_transform.shape[1]))
    self.b = random.randint(0,100)
    self.Train(X_transform,Y,learning_rate,epoches,lamda)
  def Normalization(self,X):
        #z-score normalization
      self.mu = np.mean(X,axis = 0)
      self.sigma= np.std(X,axis =0)
      X_norm = (X-self.mu)/self.sigma
      return X_norm
  def transform(self,X):
    '''Changes X into a X with having all the general terms of any degree less than self.degree'''
    a = X.copy()
    b = X.copy()
    c = X.copy()
    b = np.roll(b,1,axis =1)
    c = np.roll(c,2,axis = 1)
    for i in range(0,self.degree+1):
      for j in range(0,self.degree+1-i):
        for k in range(0,self.degree+1-i-j):
          if (i+j+k==0) or (i+j+k ==1):
            continue
          X = np.append(X,(a**i)*(b**j)*(c**k),axis =1)
    return X
  def Train(self,X,Y,learning_rate,epoches,lamda):
    X_norm = self.Normalization(X)
    self.Gradientdescent(X_norm,Y,learning_rate,epoches,lamda)
  def gradient(self,X,Y,lamda):
    m = X.shape[0]#number of training examples 
    n = X.shape[1]#number of features 
    dj_dw = np.zeros((1,n))
    dj_db = 0
    dj_db = np.sum((np.dot(self.w,X.transpose()) + self.b - Y.reshape(1,-1)),axis =1)
    dj_db /= m
    dj_dw = np.dot((np.dot(self.w,X.transpose())+self.b-Y.reshape(1,-1)),X) + 2*lamda*(self.w)
    dj_dw /= m
    return dj_dw,dj_db
  def Gradientdescent(self,X,Y,learning_rate,epoches,lamda):
    for j in range (0,epoches):
      C = self.cost_function(X,Y,lamda)
      if j%50==0:
         print(f"Cost function at {j} th iteration is :-  {C}")
         J.append(C)
         iterations.append(j)
      dj_dw,dj_db = self.gradient(X,Y,lamda)
      self.w -=(learning_rate)*(dj_dw)
      self.b -=  (learning_rate)*(dj_db)
      C_1 = self.cost_function(X,Y,lamda)
  def cost_function(self,X,Y,lamda):
    z = (np.dot(self.w,X.transpose())).reshape(1,X.shape[0]) 
    z -= Y.reshape(1,-1)
    z += self.b
    z = z**2
    z /= 2*X.shape[0]
    t = (self.w)**2
    t = t*lamda
    t /= X.shape[0]
    return np.sum(z,axis = 1) + np.sum(t,axis = 1)
  def evaluate(self,X_data):
    X_data = self.transform(X_data)
    X_data= (X_data-self.mu)/self.sigma
    Y= (np.dot(self.w,X_data.transpose()) + self.b)
    return Y
  def CVS(self,X_check,Y_check):
    Y_pred = self.evaluate(X_check)
    return (1 - (np.sum((Y_check.reshape(1,-1) - Y_pred)**2,axis = 1))/(np.sum((Y_check.reshape(1,-1) - np.mean(Y_check.reshape(1,-1),axis = 1))**2,axis = 1)))*100

# %%
Poly_model = Polynomial_Regression(X_train,Y_train,5,0.05,25000,0.1)
# Out:
# Cost function at 0 th iteration is :-  [3.17126636e+12]
# Cost function at 50 th iteration is :-  [3.1336817e+10]
# Cost function at 100 th iteration is :-  [1.0496326e+10]
# Cost function at 150 th iteration is :-  [5.02825156e+09]
# Cost function at 200 th iteration is :-  [2.6944039e+09]
# Cost function at 250 th iteration is :-  [1.54548111e+09]
# Cost function at 300 th iteration is :-  [9.42288845e+08]
# Cost function at 350 th iteration is :-  [6.07542424e+08]
# Cost function at 400 th iteration is :-  [4.11135365e+08]
# Cost function at 450 th iteration is :-  [2.89512146e+08]
# Cost function at 500 th iteration is :-  [2.10424501e+08]
# Cost function at 550 th iteration is :-  [1.5681014e+08]
# Cost function at 600 th iteration is :-  [1.19217444e+08]
# Cost function at 650 th iteration is :-  [92151959.62452686]
# Cost function at 700 th iteration is :-  [72262984.22207272]
# Cost function at 750 th iteration is :-  [57413769.55322239]
# Cost function at 800 th iteration is :-  [46187095.17651211]
# Cost function at 850 th iteration is :-  [37611598.60543758]
# Cost function at 900 th iteration is :-  [31003717.05433754]
# Cost function at 950 th iteration is :-  [25872384.25314625]
# Cost function at 1000 th iteration is :-  [21859142.20615889]
# Cost function at 1050 th iteration is :-  [18699068.78912759]
# Cost function at 1100 th iteration is :-  [16194447.57552676]
# Cost function at 1150 th iteration is :-  [14196543.87893761]
# Cost function at 1200 th iteration is :-  [12592719.34543076]
# Cost function at 1250 th iteration is :-  [11297168.16134727]
# Cost function at 1300 th iteration is :-  [10244170.7329599]
# Cost function at 1350 th iteration is :-  [9383131.62667225]
# Cost function at 1400 th iteration is :-  [8674901.40082097]
# Cost function at 1450 th iteration is :-  [8089033.13908983]
# Cost function at 1500 th iteration is :-  [7601725.62706028]
# Cost function at 1550 th iteration is :-  [7194274.4968459]
# Cost function at 1600 th iteration is :-  [6851901.25850707]
# Cost function at 1650 th iteration is :-  [6562864.73197866]
# Cost function at 1700 th iteration is :-  [6317784.33833095]
# Cost function at 1750 th iteration is :-  [6109122.87382862]
# Cost function at 1800 th iteration is :-  [5930789.71802865]
# Cost function at 1850 th iteration is :-  [5777835.26358767]
# Cost function at 1900 th iteration is :-  [5646214.64873083]
# Cost function at 1950 th iteration is :-  [5532604.30111529]
# Cost function at 2000 th iteration is :-  [5434258.85374582]
# Cost function at 2050 th iteration is :-  [5348899.02643409]
# Cost function at 2100 th iteration is :-  [5274623.34174056]
# Cost function at 2150 th iteration is :-  [5209838.25528065]
# Cost function at 2200 th iteration is :-  [5153202.5694925]
# Cost function at 2250 th iteration is :-  [5103582.97344401]
# Cost function at 2300 th iteration is :-  [5060018.2878998]
# Cost function at 2350 th iteration is :-  [5021690.55354054]
# Cost function at 2400 th iteration is :-  [4987901.52491088]
# Cost function at 2450 th iteration is :-  [4958053.45631882]
# Cost function at 2500 th iteration is :-  [4931633.31321224]
# Cost function at 2550 th iteration is :-  [4908199.7320677]
# Cost function at 2600 th iteration is :-  [4887372.19750646]
# Cost function at 2650 th iteration is :-  [4868822.01770702]
# Cost function at 2700 th iteration is :-  [4852264.76614998]
# Cost function at 2750 th iteration is :-  [4837453.92530333]
# Cost function at 2800 th iteration is :-  [4824175.52057723]
# Cost function at 2850 th iteration is :-  [4812243.57418413]
# Cost function at 2900 th iteration is :-  [4801496.24105823]
# Cost function at 2950 th iteration is :-  [4791792.51470451]
# Cost function at 3000 th iteration is :-  [4783009.41128824]
# Cost function at 3050 th iteration is :-  [4775039.55660663]
# Cost function at 3100 th iteration is :-  [4767789.11369572]
# Cost function at 3150 th iteration is :-  [4761175.99941454]
# Cost function at 3200 th iteration is :-  [4755128.34693499]
# Cost function at 3250 th iteration is :-  [4749583.17807784]
# Cost function at 3300 th iteration is :-  [4744485.25517762]
# Cost function at 3350 th iteration is :-  [4739786.08689623]
# Cost function at 3400 th iteration is :-  [4735443.06632437]
# Cost function at 3450 th iteration is :-  [4731418.7229711]
# Cost function at 3500 th iteration is :-  [4727680.07296699]
# Cost function at 3550 th iteration is :-  [4724198.05409103]
# Cost function at 3600 th iteration is :-  [4720947.03415724]
# Cost function at 3650 th iteration is :-  [4717904.38292287]
# Cost function at 3700 th iteration is :-  [4715050.09906013]
# Cost function at 3750 th iteration is :-  [4712366.48490599]
# Cost function at 3800 th iteration is :-  [4709837.8627055]
# Cost function at 3850 th iteration is :-  [4707450.32691964]
# Cost function at 3900 th iteration is :-  [4705191.52790094]
# Cost function at 3950 th iteration is :-  [4703050.48287083]
# Cost function at 4000 th iteration is :-  [4701017.41067322]
# Cost function at 4050 th iteration is :-  [4699083.58724552]
# Cost function at 4100 th iteration is :-  [4697241.21915158]
# Cost function at 4150 th iteration is :-  [4695483.33286841]
# Cost function at 4200 th iteration is :-  [4693803.67781959]
# Cost function at 4250 th iteration is :-  [4692196.64140975]
# Cost function at 4300 th iteration is :-  [4690657.17453893]
# Cost function at 4350 th iteration is :-  [4689180.72627404]
# Cost function at 4400 th iteration is :-  [4687763.18652233]
# Cost function at 4450 th iteration is :-  [4686400.83570199]
# Cost function at 4500 th iteration is :-  [4685090.30053203]
# Cost function at 4550 th iteration is :-  [4683828.51517647]
# Cost function at 4600 th iteration is :-  [4682612.68707463]
# Cost function at 4650 th iteration is :-  [4681440.26687466]
# Cost function at 4700 th iteration is :-  [4680308.9219608]
# Cost function at 4750 th iteration is :-  [4679216.51312958]
# Cost function at 4800 th iteration is :-  [4678161.07402629]
# Cost function at 4850 th iteration is :-  [4677140.79300184]
# Cost function at 4900 th iteration is :-  [4676153.99709275]
# Cost function at 4950 th iteration is :-  [4675199.13786473]
# Cost function at 5000 th iteration is :-  [4674274.77889219]
# Cost function at 5050 th iteration is :-  [4673379.58467494]
# Cost function at 5100 th iteration is :-  [4672512.31081786]
# Cost function at 5150 th iteration is :-  [4671671.79532091]
# Cost function at 5200 th iteration is :-  [4670856.95084626]
# Cost function at 5250 th iteration is :-  [4670066.757845]
# Cost function at 5300 th iteration is :-  [4669300.25844135]
# Cost function at 5350 th iteration is :-  [4668556.55098402]
# Cost function at 5400 th iteration is :-  [4667834.78518618]
# Cost function at 5450 th iteration is :-  [4667134.15778454]
# Cost function at 5500 th iteration is :-  [4666453.90865684]
# Cost function at 5550 th iteration is :-  [4665793.31734466]
# Cost function at 5600 th iteration is :-  [4665151.69993437]
# Cost function at 5650 th iteration is :-  [4664528.40625507]
# Cost function at 5700 th iteration is :-  [4663922.81735759]
# Cost function at 5750 th iteration is :-  [4663334.34324224]
# Cost function at 5800 th iteration is :-  [4662762.42080778]
# Cost function at 5850 th iteration is :-  [4662206.51199644]
# Cost function at 5900 th iteration is :-  [4661666.10211361]
# Cost function at 5950 th iteration is :-  [4661140.69830273]
# Cost function at 6000 th iteration is :-  [4660629.82815877]
# Cost function at 6050 th iteration is :-  [4660133.03846508]
# Cost function at 6100 th iteration is :-  [4659649.89404056]
# Cost function at 6150 th iteration is :-  [4659179.9766855]
# Cost function at 6200 th iteration is :-  [4658722.88421578]
# Cost function at 6250 th iteration is :-  [4658278.22957621]
# Cost function at 6300 th iteration is :-  [4657845.64002503]
# Cost function at 6350 th iteration is :-  [4657424.75638241]
# Cost function at 6400 th iteration is :-  [4657015.23233642]
# Cost function at 6450 th iteration is :-  [4656616.73380107]
# Cost function at 6500 th iteration is :-  [4656228.9383212]
# Cost function at 6550 th iteration is :-  [4655851.5345198]
# Cost function at 6600 th iteration is :-  [4655484.22158386]
# Cost function at 6650 th iteration is :-  [4655126.70878508]
# Cost function at 6700 th iteration is :-  [4654778.71503233]
# Cost function at 6750 th iteration is :-  [4654439.96845303]
# Cost function at 6800 th iteration is :-  [4654110.20600092]
# Cost function at 6850 th iteration is :-  [4653789.17308792]
# Cost function at 6900 th iteration is :-  [4653476.623238]
# Cost function at 6950 th iteration is :-  [4653172.31776141]
# Cost function at 7000 th iteration is :-  [4652876.02544737]
# Cost function at 7050 th iteration is :-  [4652587.52227398]
# Cost function at 7100 th iteration is :-  [4652306.59113385]
# Cost function at 7150 th iteration is :-  [4652033.02157427]
# Cost function at 7200 th iteration is :-  [4651766.60955093]
# Cost function at 7250 th iteration is :-  [4651507.15719409]
# Cost function at 7300 th iteration is :-  [4651254.47258633]
# Cost function at 7350 th iteration is :-  [4651008.36955113]
# Cost function at 7400 th iteration is :-  [4650768.66745143]
# Cost function at 7450 th iteration is :-  [4650535.19099763]
# Cost function at 7500 th iteration is :-  [4650307.77006424]
# Cost function at 7550 th iteration is :-  [4650086.23951488]
# Cost function at 7600 th iteration is :-  [4649870.43903473]
# Cost function at 7650 th iteration is :-  [4649660.21297044]
# Cost function at 7700 th iteration is :-  [4649455.41017659]
# Cost function at 7750 th iteration is :-  [4649255.88386865]
# Cost function at 7800 th iteration is :-  [4649061.49148191]
# Cost function at 7850 th iteration is :-  [4648872.09453609]
# Cost function at 7900 th iteration is :-  [4648687.55850529]
# Cost function at 7950 th iteration is :-  [4648507.752693]
# Cost function at 8000 th iteration is :-  [4648332.55011191]
# Cost function at 8050 th iteration is :-  [4648161.82736833]
# Cost function at 8100 th iteration is :-  [4647995.46455084]
# Cost function at 8150 th iteration is :-  [4647833.34512308]
# Cost function at 8200 th iteration is :-  [4647675.35582047]
# Cost function at 8250 th iteration is :-  [4647521.38655065]
# Cost function at 8300 th iteration is :-  [4647371.33029734]
# Cost function at 8350 th iteration is :-  [4647225.08302777]
# Cost function at 8400 th iteration is :-  [4647082.54360321]
# Cost function at 8450 th iteration is :-  [4646943.61369259]
# Cost function at 8500 th iteration is :-  [4646808.19768914]
# Cost function at 8550 th iteration is :-  [4646676.20262971]
# Cost function at 8600 th iteration is :-  [4646547.53811695]
# Cost function at 8650 th iteration is :-  [4646422.11624401]
# Cost function at 8700 th iteration is :-  [4646299.85152162]
# Cost function at 8750 th iteration is :-  [4646180.66080775]
# Cost function at 8800 th iteration is :-  [4646064.46323936]
# Cost function at 8850 th iteration is :-  [4645951.18016651]
# Cost function at 8900 th iteration is :-  [4645840.73508841]
# Cost function at 8950 th iteration is :-  [4645733.05359168]
# Cost function at 9000 th iteration is :-  [4645628.06329038]
# Cost function at 9050 th iteration is :-  [4645525.69376806]
# Cost function at 9100 th iteration is :-  [4645425.87652156]
# Cost function at 9150 th iteration is :-  [4645328.54490654]
# Cost function at 9200 th iteration is :-  [4645233.63408468]
# Cost function at 9250 th iteration is :-  [4645141.08097258]
# Cost function at 9300 th iteration is :-  [4645050.82419213]
# Cost function at 9350 th iteration is :-  [4644962.8040224]
# Cost function at 9400 th iteration is :-  [4644876.96235304]
# Cost function at 9450 th iteration is :-  [4644793.24263905]
# Cost function at 9500 th iteration is :-  [4644711.58985686]
# Cost function at 9550 th iteration is :-  [4644631.95046178]
# Cost function at 9600 th iteration is :-  [4644554.27234674]
# Cost function at 9650 th iteration is :-  [4644478.50480216]
# Cost function at 9700 th iteration is :-  [4644404.59847708]
# Cost function at 9750 th iteration is :-  [4644332.50534138]
# Cost function at 9800 th iteration is :-  [4644262.1786492]
# Cost function at 9850 th iteration is :-  [4644193.5729033]
# Cost function at 9900 th iteration is :-  [4644126.64382055]
# Cost function at 9950 th iteration is :-  [4644061.34829841]
# Cost function at 10000 th iteration is :-  [4643997.64438236]
# Cost function at 10050 th iteration is :-  [4643935.49123425]
# Cost function at 10100 th iteration is :-  [4643874.84910165]
# Cost function at 10150 th iteration is :-  [4643815.67928799]
# Cost function at 10200 th iteration is :-  [4643757.94412356]
# Cost function at 10250 th iteration is :-  [4643701.60693742]
# Cost function at 10300 th iteration is :-  [4643646.63203007]
# Cost function at 10350 th iteration is :-  [4643592.98464679]
# Cost function at 10400 th iteration is :-  [4643540.63095198]
# Cost function at 10450 th iteration is :-  [4643489.53800399]
# Cost function at 10500 th iteration is :-  [4643439.67373075]
# Cost function at 10550 th iteration is :-  [4643391.00690618]
# Cost function at 10600 th iteration is :-  [4643343.50712712]
# Cost function at 10650 th iteration is :-  [4643297.14479095]
# Cost function at 10700 th iteration is :-  [4643251.89107394]
# Cost function at 10750 th iteration is :-  [4643207.71791008]
# Cost function at 10800 th iteration is :-  [4643164.59797054]
# Cost function at 10850 th iteration is :-  [4643122.50464376]
# Cost function at 10900 th iteration is :-  [4643081.41201602]
# Cost function at 10950 th iteration is :-  [4643041.29485261]
# Cost function at 11000 th iteration is :-  [4643002.12857949]
# Cost function at 11050 th iteration is :-  [4642963.88926547]
# Cost function at 11100 th iteration is :-  [4642926.55360489]
# Cost function at 11150 th iteration is :-  [4642890.09890079]
# Cost function at 11200 th iteration is :-  [4642854.50304852]
# Cost function at 11250 th iteration is :-  [4642819.74451982]
# Cost function at 11300 th iteration is :-  [4642785.80234734]
# Cost function at 11350 th iteration is :-  [4642752.6561096]
# Cost function at 11400 th iteration is :-  [4642720.28591633]
# Cost function at 11450 th iteration is :-  [4642688.67239426]
# Cost function at 11500 th iteration is :-  [4642657.79667326]
# Cost function at 11550 th iteration is :-  [4642627.6403729]
# Cost function at 11600 th iteration is :-  [4642598.18558931]
# Cost function at 11650 th iteration is :-  [4642569.41488252]
# Cost function at 11700 th iteration is :-  [4642541.31126402]
# Cost function at 11750 th iteration is :-  [4642513.85818475]
# Cost function at 11800 th iteration is :-  [4642487.03952338]
# Cost function at 11850 th iteration is :-  [4642460.83957489]
# Cost function at 11900 th iteration is :-  [4642435.24303954]
# Cost function at 11950 th iteration is :-  [4642410.23501205]
# Cost function at 12000 th iteration is :-  [4642385.80097115]
# Cost function at 12050 th iteration is :-  [4642361.92676934]
# Cost function at 12100 th iteration is :-  [4642338.59862302]
# Cost function at 12150 th iteration is :-  [4642315.80310277]
# Cost function at 12200 th iteration is :-  [4642293.52712407]
# Cost function at 12250 th iteration is :-  [4642271.75793805]
# Cost function at 12300 th iteration is :-  [4642250.48312268]
# Cost function at 12350 th iteration is :-  [4642229.69057413]
# Cost function at 12400 th iteration is :-  [4642209.3684983]
# Cost function at 12450 th iteration is :-  [4642189.50540272]
# Cost function at 12500 th iteration is :-  [4642170.09008852]
# Cost function at 12550 th iteration is :-  [4642151.11164272]
# Cost function at 12600 th iteration is :-  [4642132.55943072]
# Cost function at 12650 th iteration is :-  [4642114.42308893]
# Cost function at 12700 th iteration is :-  [4642096.69251763]
# Cost function at 12750 th iteration is :-  [4642079.35787409]
# Cost function at 12800 th iteration is :-  [4642062.40956574]
# Cost function at 12850 th iteration is :-  [4642045.83824368]
# Cost function at 12900 th iteration is :-  [4642029.63479623]
# Cost function at 12950 th iteration is :-  [4642013.7903427]
# Cost function at 13000 th iteration is :-  [4641998.2962274]
# Cost function at 13050 th iteration is :-  [4641983.14401369]
# Cost function at 13100 th iteration is :-  [4641968.32547827]
# Cost function at 13150 th iteration is :-  [4641953.83260561]
# Cost function at 13200 th iteration is :-  [4641939.65758248]
# Cost function at 13250 th iteration is :-  [4641925.79279273]
# Cost function at 13300 th iteration is :-  [4641912.23081212]
# Cost function at 13350 th iteration is :-  [4641898.96440326]
# Cost function at 13400 th iteration is :-  [4641885.98651085]
# Cost function at 13450 th iteration is :-  [4641873.29025684]
# Cost function at 13500 th iteration is :-  [4641860.86893588]
# Cost function at 13550 th iteration is :-  [4641848.7160108]
# Cost function at 13600 th iteration is :-  [4641836.82510825]
# Cost function at 13650 th iteration is :-  [4641825.19001445]
# Cost function at 13700 th iteration is :-  [4641813.80467103]
# Cost function at 13750 th iteration is :-  [4641802.66317104]
# Cost function at 13800 th iteration is :-  [4641791.75975498]
# Cost function at 13850 th iteration is :-  [4641781.08880703]
# Cost function at 13900 th iteration is :-  [4641770.64485128]
# Cost function at 13950 th iteration is :-  [4641760.42254816]
# Cost function at 14000 th iteration is :-  [4641750.4166909]
# Cost function at 14050 th iteration is :-  [4641740.62220212]
# Cost function at 14100 th iteration is :-  [4641731.03413044]
# Cost function at 14150 th iteration is :-  [4641721.6476473]
# Cost function at 14200 th iteration is :-  [4641712.45804375]
# Cost function at 14250 th iteration is :-  [4641703.46072739]
# Cost function at 14300 th iteration is :-  [4641694.65121937]
# Cost function at 14350 th iteration is :-  [4641686.02515149]
# Cost function at 14400 th iteration is :-  [4641677.57826332]
# Cost function at 14450 th iteration is :-  [4641669.30639947]
# Cost function at 14500 th iteration is :-  [4641661.20550688]
# Cost function at 14550 th iteration is :-  [4641653.2716322]
# Cost function at 14600 th iteration is :-  [4641645.50091926]
# Cost function at 14650 th iteration is :-  [4641637.88960655]
# Cost function at 14700 th iteration is :-  [4641630.43402482]
# Cost function at 14750 th iteration is :-  [4641623.13059471]
# Cost function at 14800 th iteration is :-  [4641615.97582449]
# Cost function at 14850 th iteration is :-  [4641608.96630779]
# Cost function at 14900 th iteration is :-  [4641602.09872144]
# Cost function at 14950 th iteration is :-  [4641595.36982335]
# Cost function at 15000 th iteration is :-  [4641588.77645046]
# Cost function at 15050 th iteration is :-  [4641582.3155167]
# Cost function at 15100 th iteration is :-  [4641575.98401108]
# Cost function at 15150 th iteration is :-  [4641569.77899573]
# Cost function at 15200 th iteration is :-  [4641563.69760412]
# Cost function at 15250 th iteration is :-  [4641557.73703916]
# Cost function at 15300 th iteration is :-  [4641551.89457153]
# Cost function at 15350 th iteration is :-  [4641546.16753791]
# Cost function at 15400 th iteration is :-  [4641540.55333935]
# Cost function at 15450 th iteration is :-  [4641535.04943959]
# Cost function at 15500 th iteration is :-  [4641529.65336355]
# Cost function at 15550 th iteration is :-  [4641524.36269574]
# Cost function at 15600 th iteration is :-  [4641519.17507877]
# Cost function at 15650 th iteration is :-  [4641514.08821189]
# Cost function at 15700 th iteration is :-  [4641509.09984957]
# Cost function at 15750 th iteration is :-  [4641504.20780009]
# Cost function at 15800 th iteration is :-  [4641499.40992425]
# Cost function at 15850 th iteration is :-  [4641494.70413397]
# Cost function at 15900 th iteration is :-  [4641490.08839108]
# Cost function at 15950 th iteration is :-  [4641485.56070601]
# Cost function at 16000 th iteration is :-  [4641481.11913664]
# Cost function at 16050 th iteration is :-  [4641476.76178707]
# Cost function at 16100 th iteration is :-  [4641472.48680647]
# Cost function at 16150 th iteration is :-  [4641468.29238796]
# Cost function at 16200 th iteration is :-  [4641464.17676753]
# Cost function at 16250 th iteration is :-  [4641460.13822295]
# Cost function at 16300 th iteration is :-  [4641456.17507274]
# Cost function at 16350 th iteration is :-  [4641452.28567518]
# Cost function at 16400 th iteration is :-  [4641448.46842727]
# Cost function at 16450 th iteration is :-  [4641444.72176381]
# Cost function at 16500 th iteration is :-  [4641441.04415647]
# Cost function at 16550 th iteration is :-  [4641437.43411284]
# Cost function at 16600 th iteration is :-  [4641433.89017557]
# Cost function at 16650 th iteration is :-  [4641430.4109215]
# Cost function at 16700 th iteration is :-  [4641426.99496081]
# Cost function at 16750 th iteration is :-  [4641423.64093617]
# Cost function at 16800 th iteration is :-  [4641420.34752202]
# Cost function at 16850 th iteration is :-  [4641417.1134237]
# Cost function at 16900 th iteration is :-  [4641413.93737673]
# Cost function at 16950 th iteration is :-  [4641410.81814608]
# Cost function at 17000 th iteration is :-  [4641407.75452539]
# Cost function at 17050 th iteration is :-  [4641404.74533636]
# Cost function at 17100 th iteration is :-  [4641401.78942798]
# Cost function at 17150 th iteration is :-  [4641398.8856759]
# Cost function at 17200 th iteration is :-  [4641396.03298176]
# Cost function at 17250 th iteration is :-  [4641393.23027257]
# Cost function at 17300 th iteration is :-  [4641390.47650009]
# Cost function at 17350 th iteration is :-  [4641387.77064022]
# Cost function at 17400 th iteration is :-  [4641385.11169242]
# Cost function at 17450 th iteration is :-  [4641382.49867911]
# Cost function at 17500 th iteration is :-  [4641379.93064515]
# Cost function at 17550 th iteration is :-  [4641377.40665728]
# Cost function at 17600 th iteration is :-  [4641374.92580357]
# Cost function at 17650 th iteration is :-  [4641372.48719293]
# Cost function at 17700 th iteration is :-  [4641370.0899546]
# Cost function at 17750 th iteration is :-  [4641367.73323763]
# Cost function at 17800 th iteration is :-  [4641365.41621045]
# Cost function at 17850 th iteration is :-  [4641363.13806038]
# Cost function at 17900 th iteration is :-  [4641360.89799313]
# Cost function at 17950 th iteration is :-  [4641358.69523245]
# Cost function at 18000 th iteration is :-  [4641356.5290196]
# Cost function at 18050 th iteration is :-  [4641354.39861301]
# Cost function at 18100 th iteration is :-  [4641352.30328781]
# Cost function at 18150 th iteration is :-  [4641350.24233544]
# Cost function at 18200 th iteration is :-  [4641348.21506329]
# Cost function at 18250 th iteration is :-  [4641346.22079429]
# Cost function at 18300 th iteration is :-  [4641344.25886654]
# Cost function at 18350 th iteration is :-  [4641342.32863297]
# Cost function at 18400 th iteration is :-  [4641340.42946096]
# Cost function at 18450 th iteration is :-  [4641338.56073198]
# Cost function at 18500 th iteration is :-  [4641336.72184133]
# Cost function at 18550 th iteration is :-  [4641334.91219772]
# Cost function at 18600 th iteration is :-  [4641333.13122302]
# Cost function at 18650 th iteration is :-  [4641331.37835189]
# Cost function at 18700 th iteration is :-  [4641329.65303153]
# Cost function at 18750 th iteration is :-  [4641327.95472136]
# Cost function at 18800 th iteration is :-  [4641326.28289273]
# Cost function at 18850 th iteration is :-  [4641324.63702861]
# Cost function at 18900 th iteration is :-  [4641323.0166234]
# Cost function at 18950 th iteration is :-  [4641321.42118255]
# Cost function at 19000 th iteration is :-  [4641319.8502224]
# Cost function at 19050 th iteration is :-  [4641318.30326984]
# Cost function at 19100 th iteration is :-  [4641316.77986214]
# Cost function at 19150 th iteration is :-  [4641315.27954665]
# Cost function at 19200 th iteration is :-  [4641313.80188056]
# Cost function at 19250 th iteration is :-  [4641312.34643074]
# Cost function at 19300 th iteration is :-  [4641310.91277342]
# Cost function at 19350 th iteration is :-  [4641309.50049405]
# Cost function at 19400 th iteration is :-  [4641308.10918703]
# Cost function at 19450 th iteration is :-  [4641306.73845552]
# Cost function at 19500 th iteration is :-  [4641305.38791127]
# Cost function at 19550 th iteration is :-  [4641304.05717435]
# Cost function at 19600 th iteration is :-  [4641302.74587303]
# Cost function at 19650 th iteration is :-  [4641301.45364353]
# Cost function at 19700 th iteration is :-  [4641300.18012989]
# Cost function at 19750 th iteration is :-  [4641298.92498373]
# Cost function at 19800 th iteration is :-  [4641297.68786413]
# Cost function at 19850 th iteration is :-  [4641296.46843743]
# Cost function at 19900 th iteration is :-  [4641295.26637705]
# Cost function at 19950 th iteration is :-  [4641294.08136338]
# Cost function at 20000 th iteration is :-  [4641292.91308354]
# Cost function at 20050 th iteration is :-  [4641291.76123129]
# Cost function at 20100 th iteration is :-  [4641290.62550688]
# Cost function at 20150 th iteration is :-  [4641289.50561683]
# Cost function at 20200 th iteration is :-  [4641288.40127388]
# Cost function at 20250 th iteration is :-  [4641287.31219677]
# Cost function at 20300 th iteration is :-  [4641286.23811017]
# Cost function at 20350 th iteration is :-  [4641285.17874446]
# Cost function at 20400 th iteration is :-  [4641284.1338357]
# Cost function at 20450 th iteration is :-  [4641283.10312544]
# Cost function at 20500 th iteration is :-  [4641282.08636058]
# Cost function at 20550 th iteration is :-  [4641281.08329332]
# Cost function at 20600 th iteration is :-  [4641280.09368096]
# Cost function at 20650 th iteration is :-  [4641279.11728583]
# Cost function at 20700 th iteration is :-  [4641278.15387518]
# Cost function at 20750 th iteration is :-  [4641277.20322104]
# Cost function at 20800 th iteration is :-  [4641276.26510014]
# Cost function at 20850 th iteration is :-  [4641275.33929378]
# Cost function at 20900 th iteration is :-  [4641274.42558777]
# Cost function at 20950 th iteration is :-  [4641273.52377225]
# Cost function at 21000 th iteration is :-  [4641272.63364169]
# Cost function at 21050 th iteration is :-  [4641271.75499472]
# Cost function at 21100 th iteration is :-  [4641270.88763407]
# Cost function at 21150 th iteration is :-  [4641270.03136646]
# Cost function at 21200 th iteration is :-  [4641269.18600254]
# Cost function at 21250 th iteration is :-  [4641268.35135677]
# Cost function at 21300 th iteration is :-  [4641267.52724736]
# Cost function at 21350 th iteration is :-  [4641266.71349616]
# Cost function at 21400 th iteration is :-  [4641265.90992863]
# Cost function at 21450 th iteration is :-  [4641265.1163737]
# Cost function at 21500 th iteration is :-  [4641264.3326637]
# Cost function at 21550 th iteration is :-  [4641263.55863436]
# Cost function at 21600 th iteration is :-  [4641262.79412464]
# Cost function at 21650 th iteration is :-  [4641262.0389767]
# Cost function at 21700 th iteration is :-  [4641261.29303585]
# Cost function at 21750 th iteration is :-  [4641260.55615044]
# Cost function at 21800 th iteration is :-  [4641259.82817181]
# Cost function at 21850 th iteration is :-  [4641259.10895425]
# Cost function at 21900 th iteration is :-  [4641258.3983549]
# Cost function at 21950 th iteration is :-  [4641257.69623369]
# Cost function at 22000 th iteration is :-  [4641257.0024533]
# Cost function at 22050 th iteration is :-  [4641256.31687911]
# Cost function at 22100 th iteration is :-  [4641255.63937909]
# Cost function at 22150 th iteration is :-  [4641254.96982379]
# Cost function at 22200 th iteration is :-  [4641254.30808627]
# Cost function at 22250 th iteration is :-  [4641253.65404205]
# Cost function at 22300 th iteration is :-  [4641253.00756903]
# Cost function at 22350 th iteration is :-  [4641252.3685475]
# Cost function at 22400 th iteration is :-  [4641251.73686002]
# Cost function at 22450 th iteration is :-  [4641251.11239141]
# Cost function at 22500 th iteration is :-  [4641250.49502869]
# Cost function at 22550 th iteration is :-  [4641249.88466104]
# Cost function at 22600 th iteration is :-  [4641249.28117974]
# Cost function at 22650 th iteration is :-  [4641248.68447816]
# Cost function at 22700 th iteration is :-  [4641248.09445166]
# Cost function at 22750 th iteration is :-  [4641247.51099759]
# Cost function at 22800 th iteration is :-  [4641246.93401525]
# Cost function at 22850 th iteration is :-  [4641246.36340579]
# Cost function at 22900 th iteration is :-  [4641245.79907227]
# Cost function at 22950 th iteration is :-  [4641245.24091954]
# Cost function at 23000 th iteration is :-  [4641244.68885421]
# Cost function at 23050 th iteration is :-  [4641244.14278466]
# Cost function at 23100 th iteration is :-  [4641243.60262095]
# Cost function at 23150 th iteration is :-  [4641243.06827481]
# Cost function at 23200 th iteration is :-  [4641242.53965963]
# Cost function at 23250 th iteration is :-  [4641242.01669036]
# Cost function at 23300 th iteration is :-  [4641241.49928353]
# Cost function at 23350 th iteration is :-  [4641240.9873572]
# Cost function at 23400 th iteration is :-  [4641240.48083095]
# Cost function at 23450 th iteration is :-  [4641239.97962579]
# Cost function at 23500 th iteration is :-  [4641239.4836642]
# Cost function at 23550 th iteration is :-  [4641238.99287005]
# Cost function at 23600 th iteration is :-  [4641238.50716861]
# Cost function at 23650 th iteration is :-  [4641238.02648649]
# Cost function at 23700 th iteration is :-  [4641237.5507516]
# Cost function at 23750 th iteration is :-  [4641237.07989319]
# Cost function at 23800 th iteration is :-  [4641236.61384174]
# Cost function at 23850 th iteration is :-  [4641236.152529]
# Cost function at 23900 th iteration is :-  [4641235.69588793]
# Cost function at 23950 th iteration is :-  [4641235.24385267]
# Cost function at 24000 th iteration is :-  [4641234.79635855]
# Cost function at 24050 th iteration is :-  [4641234.35334202]
# Cost function at 24100 th iteration is :-  [4641233.91474067]
# Cost function at 24150 th iteration is :-  [4641233.48049319]
# Cost function at 24200 th iteration is :-  [4641233.05053934]
# Cost function at 24250 th iteration is :-  [4641232.62481993]
# Cost function at 24300 th iteration is :-  [4641232.20327681]
# Cost function at 24350 th iteration is :-  [4641231.78585285]
# Cost function at 24400 th iteration is :-  [4641231.37249188]
# Cost function at 24450 th iteration is :-  [4641230.96313875]
# Cost function at 24500 th iteration is :-  [4641230.55773923]
# Cost function at 24550 th iteration is :-  [4641230.15624003]
# Cost function at 24600 th iteration is :-  [4641229.75858878]
# Cost function at 24650 th iteration is :-  [4641229.36473401]
# Cost function at 24700 th iteration is :-  [4641228.97462511]
# Cost function at 24750 th iteration is :-  [4641228.58821235]
# Cost function at 24800 th iteration is :-  [4641228.20544685]
# Cost function at 24850 th iteration is :-  [4641227.82628054]
# Cost function at 24900 th iteration is :-  [4641227.45066617]
# Cost function at 24950 th iteration is :-  [4641227.07855729]

# %%
plt.xlabel("No. of iterations at alpha = 0.05 and lambda = 0.1")
plt.ylabel("Cost function value")
plt.plot(iterations,J)
plt.show()

# %%
plt.scatter(X_train.transpose()[0],Y_train,label= "feature 1")
plt.scatter(X_train.transpose()[0],Poly_model.evaluate(X_train),ls = '',marker = 'X',label = "Prediction")
plt.legend()
plt.ylabel("Value of Y ")
plt.xlabel("Value with learning rate = 0.05 and lambda = 0.1 ")
# Out:
# Text(0.5, 0, 'Value with learning rate = 0.05 and lambda = 0.1 ')

# %%
print(Poly_model.CVS(X_CVS,Y_CVS))
# Out:
# [100.]

# %%
output = Poly_model.evaluate(X_test)

# %%
df1["output label"]=output.transpose()
a = np.array(df1.columns)
df2 = df1.drop(a[1:-1],axis = 1 )
df2
df2.to_csv('/content/drive/MyDrive/Project(WOC)/Polynomial_regression_output(1).csv')
